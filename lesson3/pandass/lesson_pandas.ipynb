# %%
import numpy as np
import pandas as pd

# %%
labels = ["a", "b", "c"]
my_list = [10, 20, 30]
arr = np.array(my_list)
d = {"a": 10, "b": 20, "c":30}

# %%
pd.Series(data=my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4],index=['Almaty','Astana','Atyrau','Kostanay'])

# %%
ser1
# Out:
# Almaty      1
# Astana      2
# Atyrau      3
# Kostanay    4
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,4],index=['Almaty','Astana','Shymkent','Kostanay'])

# %%
ser2
# Out:
# Almaty      1
# Astana      2
# Shymkent    5
# Kostanay    4
# dtype: int64

# %%
ser1+ser2
# Out:
# Almaty      2.0
# Astana      4.0
# Atyrau      NaN
# Kostanay    8.0
# Shymkent    NaN
# dtype: float64

# %%
ser3 = pd.Series([4,3,5,1],index=['Shymkent','Kostanay','Almaty','Astana'])
ser4 = pd.Series([5,3,2,7],index=['Almaty','Atyrau','Astana','Kostanay'])

# %%
(ser3+ser4).dropna().astype("int")
# Out:
# Almaty      10
# Astana       3
# Kostanay    10
# dtype: int64

# %%
ser4.dtype
# Out:
# dtype('int64')

# %%
ser3 = pd.Series([4,3,5,1],index=['Shymkent','Kostanay','Almaty','Astana'])
ser4 = pd.Series([5,3,2,7],index=['Almaty','Shymkent','Astana','Kostanay'])

# %%
ser3+ser4
# Out:
# Almaty      10
# Astana       3
# Kostanay    10
# Shymkent     7
# dtype: int64

# %%
np.random.seed(42)

# %%
from numpy.random import randn
randn(1)
# Out:
# array([0.49671415])

# %%
df = pd.DataFrame(randn(5,4),index=['A', 'B', 'C', 'D', 'E'],columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A -0.225776  0.067528 -1.424748 -0.544383
# B  0.110923 -1.150994  0.375698 -0.600639
# C -0.291694 -0.601707  1.852278 -0.013497
# D -1.057711  0.822545 -1.220844  0.208864
# E -1.959670 -1.328186  0.196861  0.738467

# %%
df["W"]
# Out:
# A   -0.225776
# B    0.110923
# C   -0.291694
# D   -1.057711
# E   -1.959670
# Name: W, dtype: float64

# %%
type(df["W"])
# Out:
# pandas.core.series.Series

# %%
df[["W", "Z"]]
# Out:
#           W         Z
# A -0.225776 -0.544383
# B  0.110923 -0.600639
# C -0.291694 -0.013497
# D -1.057711  0.208864
# E -1.959670  0.738467

# %%
cols = ["W", "Z"]
df[cols]
# Out:
#           W         Z
# A -0.225776 -0.544383
# B  0.110923 -0.600639
# C -0.291694 -0.013497
# D -1.057711  0.208864
# E -1.959670  0.738467

# %%
type(df[cols])
# Out:
# pandas.core.frame.DataFrame

# %%
cols = ["W"]
type(df[cols])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["W"])
# Out:
# pandas.core.series.Series

# %%
df[["W"]]
# Out:
#           W
# A -0.225776
# B  0.110923
# C -0.291694
# D -1.057711
# E -1.959670

# %%
df["W"]
# Out:
# A   -0.225776
# B    0.110923
# C   -0.291694
# D   -1.057711
# E   -1.959670
# Name: W, dtype: float64

# %%
cols
# Out:
# ['W']

# %%
df["new"] = df["W"] + df["Y"]

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.225776  0.067528 -1.424748 -0.544383 -1.650524
# B  0.110923 -1.150994  0.375698 -0.600639  0.486621
# C -0.291694 -0.601707  1.852278 -0.013497  1.560584
# D -1.057711  0.822545 -1.220844  0.208864 -2.278555
# E -1.959670 -1.328186  0.196861  0.738467 -1.762809

# %%
df["K"] = 0

# %%
df
# Out:
#           W         X         Y         Z       new  K
# A -0.225776  0.067528 -1.424748 -0.544383 -1.650524  0
# B  0.110923 -1.150994  0.375698 -0.600639  0.486621  0
# C -0.291694 -0.601707  1.852278 -0.013497  1.560584  0
# D -1.057711  0.822545 -1.220844  0.208864 -2.278555  0
# E -1.959670 -1.328186  0.196861  0.738467 -1.762809  0

# %%
df.drop("K", axis=1)
# Out:
#           W         X         Y         Z       new
# A -0.225776  0.067528 -1.424748 -0.544383 -1.650524
# B  0.110923 -1.150994  0.375698 -0.600639  0.486621
# C -0.291694 -0.601707  1.852278 -0.013497  1.560584
# D -1.057711  0.822545 -1.220844  0.208864 -2.278555
# E -1.959670 -1.328186  0.196861  0.738467 -1.762809

# %%
df
# Out:
#           W         X         Y         Z       new  K
# A -0.225776  0.067528 -1.424748 -0.544383 -1.650524  0
# B  0.110923 -1.150994  0.375698 -0.600639  0.486621  0
# C -0.291694 -0.601707  1.852278 -0.013497  1.560584  0
# D -1.057711  0.822545 -1.220844  0.208864 -2.278555  0
# E -1.959670 -1.328186  0.196861  0.738467 -1.762809  0

# %%
df.drop("K", axis=1, inplace=True)

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.225776  0.067528 -1.424748 -0.544383 -1.650524
# B  0.110923 -1.150994  0.375698 -0.600639  0.486621
# C -0.291694 -0.601707  1.852278 -0.013497  1.560584
# D -1.057711  0.822545 -1.220844  0.208864 -2.278555
# E -1.959670 -1.328186  0.196861  0.738467 -1.762809

# %%
X = df.drop("new", axis=1)
Y = df["new"]

# %%
X
# Out:
#           W         X         Y         Z
# A -0.225776  0.067528 -1.424748 -0.544383
# B  0.110923 -1.150994  0.375698 -0.600639
# C -0.291694 -0.601707  1.852278 -0.013497
# D -1.057711  0.822545 -1.220844  0.208864
# E -1.959670 -1.328186  0.196861  0.738467

# %%
Y
# Out:
# A   -1.650524
# B    0.486621
# C    1.560584
# D   -2.278555
# E   -1.762809
# Name: new, dtype: float64

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.225776  0.067528 -1.424748 -0.544383 -1.650524
# B  0.110923 -1.150994  0.375698 -0.600639  0.486621
# C -0.291694 -0.601707  1.852278 -0.013497  1.560584
# D -1.057711  0.822545 -1.220844  0.208864 -2.278555
# E -1.959670 -1.328186  0.196861  0.738467 -1.762809

# %%
df["Y"][1] = 1

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.225776  0.067528 -1.424748 -0.544383 -1.650524
# B  0.110923 -1.150994  1.000000 -0.600639  0.486621
# C -0.291694 -0.601707  1.852278 -0.013497  1.560584
# D -1.057711  0.822545 -1.220844  0.208864 -2.278555
# E -1.959670 -1.328186  0.196861  0.738467 -1.762809

# %%
X
# Out:
#           W         X         Y         Z
# A -0.225776  0.067528 -1.424748 -0.544383
# B  0.110923 -1.150994  0.375698 -0.600639
# C -0.291694 -0.601707  1.852278 -0.013497
# D -1.057711  0.822545 -1.220844  0.208864
# E -1.959670 -1.328186  0.196861  0.738467

# %%
df.drop("E")
# Out:
#           W         X         Y         Z       new
# A -0.225776  0.067528 -1.424748 -0.544383 -1.650524
# B  0.110923 -1.150994  1.000000 -0.600639  0.486621
# C -0.291694 -0.601707  1.852278 -0.013497  1.560584
# D -1.057711  0.822545 -1.220844  0.208864 -2.278555

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.225776  0.067528 -1.424748 -0.544383 -1.650524
# B  0.110923 -1.150994  1.000000 -0.600639  0.486621
# C -0.291694 -0.601707  1.852278 -0.013497  1.560584
# D -1.057711  0.822545 -1.220844  0.208864 -2.278555
# E -1.959670 -1.328186  0.196861  0.738467 -1.762809

# %%
df.loc["A"]
# Out:
# W     -0.225776
# X      0.067528
# Y     -1.424748
# Z     -0.544383
# new   -1.650524
# Name: A, dtype: float64

# %%
type(df.loc["A"])
# Out:
# pandas.core.series.Series

# %%
df.iloc[1]
# Out:
# W      0.110923
# X     -1.150994
# Y      1.000000
# Z     -0.600639
# new    0.486621
# Name: B, dtype: float64

# %%
df.loc["B","Y"]
# Out:
# 1.0

# %%
df.loc["C", "new"]
# Out:
# 1.560584434715661

# %%
df > 0
# Out:
#        W      X      Y      Z    new
# A  False   True  False  False  False
# B   True  False   True  False   True
# C  False  False   True  False   True
# D  False   True  False   True  False
# E  False  False   True   True  False

# %%
df[df>0]
# Out:
#           W         X         Y         Z       new
# A       NaN  0.067528       NaN       NaN       NaN
# B  0.110923       NaN  1.000000       NaN  0.486621
# C       NaN       NaN  1.852278       NaN  1.560584
# D       NaN  0.822545       NaN  0.208864       NaN
# E       NaN       NaN  0.196861  0.738467       NaN

# %%
df["X"] > 0
# Out:
# A     True
# B    False
# C    False
# D     True
# E    False
# Name: X, dtype: bool

# %%
df[df["X"]>0]
# Out:
#           W         X         Y         Z       new
# A -0.225776  0.067528 -1.424748 -0.544383 -1.650524
# D -1.057711  0.822545 -1.220844  0.208864 -2.278555

# %%
df[[True, True, True, False, True]]
# Out:
#           W         X         Y         Z       new
# A -0.225776  0.067528 -1.424748 -0.544383 -1.650524
# B  0.110923 -1.150994  1.000000 -0.600639  0.486621
# C -0.291694 -0.601707  1.852278 -0.013497  1.560584
# E -1.959670 -1.328186  0.196861  0.738467 -1.762809

# %%
df[df["X"]>0]
# Out:
#           W         X         Y         Z       new
# A -0.225776  0.067528 -1.424748 -0.544383 -1.650524
# D -1.057711  0.822545 -1.220844  0.208864 -2.278555

# %%
df[df["X"]>0][["Y","Z"]]
# Out:
#           Y         Z
# A -1.424748 -0.544383
# D -1.220844  0.208864

# %%
df[(df["X"]>0) | (df["Z"]>0)]
# Out:
#           W         X         Y         Z       new
# A -0.225776  0.067528 -1.424748 -0.544383 -1.650524
# D -1.057711  0.822545 -1.220844  0.208864 -2.278555
# E -1.959670 -1.328186  0.196861  0.738467 -1.762809

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.225776  0.067528 -1.424748 -0.544383 -1.650524
# B  0.110923 -1.150994  1.000000 -0.600639  0.486621
# C -0.291694 -0.601707  1.852278 -0.013497  1.560584
# D -1.057711  0.822545 -1.220844  0.208864 -2.278555
# E -1.959670 -1.328186  0.196861  0.738467 -1.762809

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z       new
# 0     A -0.225776  0.067528 -1.424748 -0.544383 -1.650524
# 1     B  0.110923 -1.150994  1.000000 -0.600639  0.486621
# 2     C -0.291694 -0.601707  1.852278 -0.013497  1.560584
# 3     D -1.057711  0.822545 -1.220844  0.208864 -2.278555
# 4     E -1.959670 -1.328186  0.196861  0.738467 -1.762809

# %%
newind = 'ALA AST SHY ATY KOS'.split()

# %%
newind
# Out:
# ['ALA', 'AST', 'SHY', 'ATY', 'KOS']

# %%
df["city"] = newind

# %%
df
# Out:
#           W         X         Y         Z       new city
# A -0.225776  0.067528 -1.424748 -0.544383 -1.650524  ALA
# B  0.110923 -1.150994  1.000000 -0.600639  0.486621  AST
# C -0.291694 -0.601707  1.852278 -0.013497  1.560584  SHY
# D -1.057711  0.822545 -1.220844  0.208864 -2.278555  ATY
# E -1.959670 -1.328186  0.196861  0.738467 -1.762809  KOS

# %%
df.set_index("city", inplace=True)

# %%
df.loc["ALA"]
# Out:
# W     -0.225776
# X      0.067528
# Y     -1.424748
# Z     -0.544383
# new   -1.650524
# Name: ALA, dtype: float64

# %% [markdown]
# ## Multiindex

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#   city         W         X         Y         Z       new
# 0  ALA -0.225776  0.067528 -1.424748 -0.544383 -1.650524
# 1  AST  0.110923 -1.150994  1.000000 -0.600639  0.486621
# 2  SHY -0.291694 -0.601707  1.852278 -0.013497  1.560584
# 3  ATY -1.057711  0.822545 -1.220844  0.208864 -2.278555
# 4  KOS -1.959670 -1.328186  0.196861  0.738467 -1.762809

# %%
outside = ["BIG", "BIG", "BIG", "SMALL", "SMALL"]
inside = ["A1", "A2", "A3", "A1", "A2"]
hier_index = list(zip(outside, inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
df.set_index(hier_index, inplace=True)

# %%
df
# Out:
#          city         W         X         Y         Z       new
# BIG   A1  ALA -0.225776  0.067528 -1.424748 -0.544383 -1.650524
#       A2  AST  0.110923 -1.150994  1.000000 -0.600639  0.486621
#       A3  SHY -0.291694 -0.601707  1.852278 -0.013497  1.560584
# SMALL A1  ATY -1.057711  0.822545 -1.220844  0.208864 -2.278555
#       A2  KOS -1.959670 -1.328186  0.196861  0.738467 -1.762809

# %%
df.loc["SMALL"]
# Out:
#    city         W         X         Y         Z       new
# A1  ATY -1.057711  0.822545 -1.220844  0.208864 -2.278555
# A2  KOS -1.959670 -1.328186  0.196861  0.738467 -1.762809

# %%
df.xs("A2", level=1)
# Out:
#       city         W         X         Y         Z       new
# BIG    AST  0.110923 -1.150994  1.000000 -0.600639  0.486621
# SMALL  KOS -1.959670 -1.328186  0.196861  0.738467 -1.762809

# %%
df.xs("BIG", level=0)
# Out:
#    city         W         X         Y         Z       new
# A1  ALA -0.225776  0.067528 -1.424748 -0.544383 -1.650524
# A2  AST  0.110923 -1.150994  1.000000 -0.600639  0.486621
# A3  SHY -0.291694 -0.601707  1.852278 -0.013497  1.560584

# %%
df = pd.DataFrame({
    "A": [1, 2, np.nan],
    "B": [5, np.nan, np.nan],
    "C": [1, 2, 3],
})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna(axis=1, thresh=2)
# Out:
#      A  C
# 0  1.0  1
# 1  2.0  2
# 2  NaN  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(df["C"].mean())
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  2.0  2
# 2  2.0  2.0  3

# %%
df = pd.DataFrame({
    "a": [1, 2, 3, 4, np.nan, 3, 4, 3, np.nan, 4, 5, 3],
    "b": np.arange(12),
})

# %%
df
# Out:
#       a   b
# 0   1.0   0
# 1   2.0   1
# 2   3.0   2
# 3   4.0   3
# 4   NaN   4
# 5   3.0   5
# 6   4.0   6
# 7   3.0   7
# 8   NaN   8
# 9   4.0   9
# 10  5.0  10
# 11  3.0  11

# %%
df["a"].fillna(df["a"].mean(), inplace=True)

# %%
df
# Out:
#       a   b
# 0   1.0   0
# 1   2.0   1
# 2   3.0   2
# 3   4.0   3
# 4   3.2   4
# 5   3.0   5
# 6   4.0   6
# 7   3.0   7
# 8   3.2   8
# 9   4.0   9
# 10  5.0  10
# 11  3.0  11

# %% [markdown]
# ## Group By

# %%
data = {'Company':['GOOG','GOOG','MSFT','MSFT','META','META'],
       'Person':['Asan','Zhuldyz','Didar','Arman','Daniyar','Nurlan'],
       'Sales':[220,130,650,124,354,4600]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG     Asan    220
# 1    GOOG  Zhuldyz    130
# 2    MSFT    Didar    650
# 3    MSFT    Arman    124
# 4    META  Daniyar    354
# 5    META   Nurlan   4600

# %%
by_comp = df.groupby("Company")

# %%
by_comp.mean(numeric_only=True)
# Out:
#           Sales
# Company
# GOOG      175.0
# META     2477.0
# MSFT      387.0

# %%
by_comp.std(numeric_only=True)
# Out:
#                Sales
# Company
# GOOG       63.639610
# META     3002.375393
# MSFT      371.938167

# %%
by_comp.min()
# Out:
#           Person  Sales
# Company
# GOOG        Asan    130
# META     Daniyar    354
# MSFT       Arman    124

# %%
by_comp.max()
# Out:
#           Person  Sales
# Company
# GOOG     Zhuldyz    220
# META      Nurlan   4600
# MSFT       Didar    650

# %%
by_comp.sum(numeric_only=True)
# Out:
#          Sales
# Company
# GOOG       350
# META      4954
# MSFT       774

# %%
by_comp.describe()
# Out:
#         Sales
#         count    mean          std    min     25%     50%     75%     max
# Company
# GOOG      2.0   175.0    63.639610  130.0   152.5   175.0   197.5   220.0
# META      2.0  2477.0  3002.375393  354.0  1415.5  2477.0  3538.5  4600.0
# MSFT      2.0   387.0   371.938167  124.0   255.5   387.0   518.5   650.0

# %%
by_comp.aggregate([max, sum, min])
# Out:
#           Person                         Sales
#              max            sum      min   max   sum  min
# Company
# GOOG     Zhuldyz    AsanZhuldyz     Asan   220   350  130
# META      Nurlan  DaniyarNurlan  Daniyar  4600  4954  354
# MSFT       Didar     DidarArman    Arman   650   774  124

# %%
by_comp.describe().T
# Out:
# Company           GOOG         META        MSFT
# Sales count    2.00000     2.000000    2.000000
#       mean   175.00000  2477.000000  387.000000
#       std     63.63961  3002.375393  371.938167
#       min    130.00000   354.000000  124.000000
#       25%    152.50000  1415.500000  255.500000
#       50%    175.00000  2477.000000  387.000000
#       75%    197.50000  3538.500000  518.500000
#       max    220.00000  4600.000000  650.000000

# %%
by_comp.describe().T["GOOG"]
# Out:
# Sales  count      2.00000
#        mean     175.00000
#        std       63.63961
#        min      130.00000
#        25%      152.50000
#        50%      175.00000
#        75%      197.50000
#        max      220.00000
# Name: GOOG, dtype: float64

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7]) 

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1, df2, df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1.reset_index(), df2.reset_index(), df3.reset_index()], axis=1)
# Out:
#    index   A   B   C   D  index   A   B   C   D  index    A    B    C    D
# 0      0  A0  B0  C0  D0      4  A4  B4  C4  D4      8   A8   B8   C8   D8
# 1      1  A1  B1  C1  D1      5  A5  B5  C5  D5      9   A9   B9   C9   D9
# 2      2  A2  B2  C2  D2      6  A6  B6  C6  D6     10  A10  B10  C10  D10
# 3      3  A3  B3  C3  D3      7  A7  B7  C7  D7     11  A11  B11  C11  D11

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
# SELECT * FROM table1 INNER JOIN table2 ON table1.key == table2.key
pd.merge(left, right, how="outer", on="key")
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(left, right, on=['key1', 'key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
pd.merge(left, right, how="outer", on=['key1', 'key2'])
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K1   A3   B3  NaN  NaN
# 5   K2   K0  NaN  NaN   C3   D3

# %%
pd.merge(left, right, how='left', on=['key1', 'key2'])
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %% [markdown]
# ### Join

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
pwd
# Out:
# '/Users/timurbakibayev/jupyter/pandass'

# %%
df = pd.read_csv("example.csv")

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df = pd.read_csv("example1.csv", sep=".")

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       4 non-null      int64
#  1   b       4 non-null      int64
#  2   c       4 non-null      int64
#  3   d       4 non-null      int64
# dtypes: int64(4)
# memory usage: 256.0 bytes

# %%
df.head(2)
# Out:
#    a  b  c  d
# 0  0  1  2  3
# 1  4  5  6  7

# %%
df2 = df*2

# %%
df2
# Out:
#     a   b   c   d
# 0   0   2   4   6
# 1   8  10  12  14
# 2  16  18  20  22
# 3  24  26  28  30

# %%
df.to_csv("example2.csv", index=False)

# %%
df = pd.read_excel("Excel_Sample.xlsx")

# %%
df
# Out:
#    ind   a   b   c   d
# 0    0   0   1   2   3
# 1    1   4   5   6   7
# 2    2   8   9  20  11
# 3    3  12  13  14  15

# %%
df["e"] = df["d"]**2 + df["c"]

# %%
df.to_excel("Excel_Sample.xlsx", index=False)

# %%
df.to_html("ddd.html")

# %%
df = pd.read_html("https://www.nationalbank.kz/ru/exchangerates/ezhednevnye-oficialnye-rynochnye-kursy-valyut")

# %%
df = df[0]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      0                                           1          2        3   4
# 0  NaN                      1 АВСТРАЛИЙСКИЙ ДОЛЛАР  AUD / KZT   303.81 NaN
# 1  NaN                     1 АЗЕРБАЙДЖАНСКИЙ МАНАТ  AZN / KZT   264.67 NaN
# 2  NaN                           10 АРМЯНСКИЙ ДРАМ  AMD / KZT    11.64 NaN
# 3  NaN                         1 БЕЛОРУССКИЙ РУБЛЬ  BYN / KZT   178.16 NaN
# 4  NaN                          1 БРАЗИЛЬСКИЙ РЕАЛ  BRL / KZT    92.28 NaN
# 5  NaN                      10 ВЕНГЕРСКИХ ФОРИНТОВ  HUF / KZT    13.07 NaN
# 6  NaN                        1 ГОНКОНГСКИЙ ДОЛЛАР  HKD / KZT    57.27 NaN
# 7  NaN                           1 ГРУЗИНСКИЙ ЛАРИ  GEL / KZT   174.22 NaN
# 8  NaN                             1 ДАТСКАЯ КРОНА  DKK / KZT    65.05 NaN
# 9  NaN                                1 ДИРХАМ ОАЭ  AED / KZT   122.16 NaN
# 10 NaN                                1 ДОЛЛАР США  USD / KZT   448.62 NaN
# ...

# %%
tables = pd.read_html("https://en.wikipedia.org/wiki/Kazakhstan")

# %%
len(tables)
# Out:
# 36

# %%
tables[6]
# Out:
#    Largest cities or towns in Kazakhstan [1]                                 \
#                           Unnamed: 0_level_1                Rank       Name
# 0                              Almaty Astana                   1     Almaty
# 1                              Almaty Astana                   2     Astana
# 2                              Almaty Astana                   3   Shymkent
# 3                              Almaty Astana                   4  Karaganda
# 4                              Almaty Astana                   5     Aktobe
# 5                              Almaty Astana                   6      Taraz
# 6                              Almaty Astana                   7   Pavlodar
# 7                              Almaty Astana                   8    Oskemen
# 8                              Almaty Astana                   9      Semey
# 9                              Almaty Astana                  10     Atyrau
# ...
