# %%
import matplotlib.pyplot as plt
import numpy as np
# to not write plt.show() each time,
# %matplotlib inline

# %%
x = np.linspace(-5, 5, 100)
y = x ** 2

# %%
x
# Out:
# array([-5.        , -4.8989899 , -4.7979798 , -4.6969697 , -4.5959596 ,
#        -4.49494949, -4.39393939, -4.29292929, -4.19191919, -4.09090909,
#        -3.98989899, -3.88888889, -3.78787879, -3.68686869, -3.58585859,
#        -3.48484848, -3.38383838, -3.28282828, -3.18181818, -3.08080808,
#        -2.97979798, -2.87878788, -2.77777778, -2.67676768, -2.57575758,
#        -2.47474747, -2.37373737, -2.27272727, -2.17171717, -2.07070707,
#        -1.96969697, -1.86868687, -1.76767677, -1.66666667, -1.56565657,
#        -1.46464646, -1.36363636, -1.26262626, -1.16161616, -1.06060606,
#        -0.95959596, -0.85858586, -0.75757576, -0.65656566, -0.55555556,
#        -0.45454545, -0.35353535, -0.25252525, -0.15151515, -0.05050505,
#         0.05050505,  0.15151515,  0.25252525,  0.35353535,  0.45454545,
#         0.55555556,  0.65656566,  0.75757576,  0.85858586,  0.95959596,
#         1.06060606,  1.16161616,  1.26262626,  1.36363636,  1.46464646,
# ...

# %%
y
# Out:
# array([2.50000000e+01, 2.40001020e+01, 2.30206101e+01, 2.20615243e+01,
#        2.11228446e+01, 2.02045710e+01, 1.93067034e+01, 1.84292419e+01,
#        1.75721865e+01, 1.67355372e+01, 1.59192939e+01, 1.51234568e+01,
#        1.43480257e+01, 1.35930007e+01, 1.28583818e+01, 1.21441690e+01,
#        1.14503622e+01, 1.07769615e+01, 1.01239669e+01, 9.49137843e+00,
#        8.87919600e+00, 8.28741965e+00, 7.71604938e+00, 7.16508520e+00,
#        6.63452709e+00, 6.12437506e+00, 5.63462912e+00, 5.16528926e+00,
#        4.71635547e+00, 4.28782777e+00, 3.87970615e+00, 3.49199061e+00,
#        3.12468115e+00, 2.77777778e+00, 2.45128048e+00, 2.14518927e+00,
#        1.85950413e+00, 1.59422508e+00, 1.34935211e+00, 1.12488522e+00,
#        9.20824406e-01, 7.37169677e-01, 5.73921028e-01, 4.31078461e-01,
#        3.08641975e-01, 2.06611570e-01, 1.24987246e-01, 6.37690032e-02,
#        2.29568411e-02, 2.55076013e-03, 2.55076013e-03, 2.29568411e-02,
# ...

# %%
x = np.linspace(-5, 5, 10)
y = x ** 2

x1 = np.linspace(-5, 5, 10)
y1 = x1 ** 2

plt.plot(x,y, "r")
plt.plot(x1,y1+1, "g")
plt.scatter(x1,y1+2, c="r")

# %%
plt.plot(x,y,"r")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Some title")
# Out:
# Text(0.5, 1.0, 'Some title')

# %%
plt.subplot(1,2,1)  # 1 row x 2 col, current number 1
plt.plot(x,y, "b--")
plt.subplot(1,2,2)  # graph number 2
plt.plot(y,x, color="g", marker="^", linestyle="--")

# %%
fig = plt.figure(figsize=(10,5))

axes_blue = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes_blue.plot(x,y,"b")
axes_blue.set_xlabel("X label axes 1")
axes_blue.set_ylabel("Y label axes 1")
axes_blue.set_title("Ax 1 title")

axes2.plot(x,y,"r")
axes2.set_xlabel("X label axes 2")
axes2.set_ylabel("Y label axes 2")
axes2.set_title("Ax 2 title")

fig.savefig("two_beautiful_graphs.png", dpi=300)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
line1, = ax.plot(x, x**2, label="x**2", color="#8B006B", alpha=0.5)
line2, = ax.plot(x, x**3, label="x**3")
ax.legend(loc='best', bbox_to_anchor=(0.5, 0., 0.5, 0.5))

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color='red', linewidth=0.25)
ax.plot(x, x+2, color='red', linewidth=0.50)
ax.plot(x, x+3, color='red', linewidth=1)
ax.plot(x, x+4, color='red', linewidth=2)

# '-','-.',':','steps'
ax.plot(x, x+5, color='green', lw=3, linestyle='-')
ax.plot(x, x+6, color='green', lw=3, ls='-.')
ax.plot(x, x+7, color='green', lw=3, ls=':')

line, = ax.plot(x, x+8, color='black',lw='1.5')
line.set_dashes([5,10,15,5])

# marker = '+','o', '*', 's', ',', '.','1','2',...
ax.plot(x, x+9, color='blue', lw=3, ls='-',marker ='+')
ax.plot(x, x+10, color='blue', lw=3, ls='--',marker ='o')
ax.plot(x, x+11, color='blue', lw=3, ls='-',marker ='s')
ax.plot(x, x+12, color='blue', lw=3, ls='--',marker ='1')

ax.plot(x, x+13, color='purple', lw=1, ls='-',marker ='o', markersize=2)
ax.plot(x, x+14, color='purple', lw=1, ls='-',marker ='o', markersize=4)
ax.plot(x, x+15, color='purple', lw=1, ls='-',marker ='o', markersize=8, markerfacecolor='red')
ax.plot(x, x+16, color='purple', lw=1, ls='-',marker ='s', markersize=8, 
       markerfacecolor='yellow', markeredgewidth=3, markeredgecolor='green')

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data, bins=5)
# Out:
# (array([23., 25., 13., 19., 20.]),
#  array([  2. , 200.2, 398.4, 596.6, 794.8, 993. ]),
#  <BarContainer object of 5 artists>)

# %%
data = [np.random.normal(0,std,100) for std in range(1,4)]

plt.boxplot(data, vert=True, patch_artist=True);

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.distplot(tips["total_bill"])
# Out:
# /var/folders/66/3xy4pms51yv71qx6t0_h8ht00000gn/T/ipykernel_72930/1984207902.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips["total_bill"], kde=False, bins=30)
# Out:
# /var/folders/66/3xy4pms51yv71qx6t0_h8ht00000gn/T/ipykernel_72930/2773053801.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"], kde=False, bins=30)
# <Axes: xlabel='total_bill'>

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="scatter")

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg")

# %%
sns.pairplot(tips)

# %%
tips['sex'].unique()
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Male', 'Female']

# %%
sns.pairplot(tips,hue='sex',palette="viridis")

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.kdeplot(tips['total_bill'])
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(tips['tip'])
sns.rugplot(tips['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.barplot(x='sex',y='total_bill',data=tips, estimator=np.mean)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
tips.groupby('sex')['total_bill'].std()
# Out:
# sex
# Male      9.246469
# Female    8.009209
# Name: total_bill, dtype: float64

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %% [markdown]
# ## boxplot and violinplot
#
# boxplots и violinplots используются для отображения распределения категориальных данных. Коробчатая диаграмма (или диаграмма «ящик с усами») показывает распределение количественных данных таким образом, чтобы облегчить сравнение между переменными или между уровнями категориальной переменной. В рамке показаны квартили набора данных, в то время как усы расширяются, чтобы показать остальную часть распределения, за исключением точек, которые определены как «выбросы» с использованием метода, который является функцией межквартильного диапазона.
#
# ![IQR-boxplot.jpg](attachment:IQR-boxplot.jpg)

# %%
sns.boxplot(x="day", y="total_bill", data=tips,palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="total_bill", data=tips,palette='tab10')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips,palette='rainbow',orient='h')
# Out:
# <Axes: >

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="coolwarm")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.violinplot(x="day", y="total_bill", data=tips,palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',split=True,palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True,hue='sex',palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y="total_bill", data=tips, hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tips.corr()
# Out:
# /var/folders/66/3xy4pms51yv71qx6t0_h8ht00000gn/T/ipykernel_72930/3825555837.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tips.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(), cmap="viridis")
# Out:
# /var/folders/66/3xy4pms51yv71qx6t0_h8ht00000gn/T/ipykernel_72930/1223953736.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr(), cmap="viridis")
# <Axes: >

# %%
sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)
# Out:
# /var/folders/66/3xy4pms51yv71qx6t0_h8ht00000gn/T/ipykernel_72930/1408459415.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)
# <Axes: >

# %%
a = flights.pivot_table(values='passengers',index='month',columns='year')

# %%
plt.figure(figsize=(15,5))
sns.heatmap(a, annot=True)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(a,cmap='magma',linecolor='white',linewidths=1)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(a)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm',
           markers=['o','v'],scatter_kws={'s':100})
